# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !unzip -q "HAM_CLEAN_SPLIT.zip" -d /content/dataset

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import mixed_precision
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# %%
CLEAN_ROOT = "/content/dataset/HAM_CLEAN_SPLIT"
TRAIN_DIR  = os.path.join(CLEAN_ROOT, "train")
VAL_DIR    = os.path.join(CLEAN_ROOT, "val")
TEST_DIR   = os.path.join(CLEAN_ROOT, "test")

print("TRAIN_DIR:", TRAIN_DIR)
print("VAL_DIR  :", VAL_DIR)
print("TEST_DIR :", TEST_DIR)
# Out:
# TRAIN_DIR: /content/dataset/HAM_CLEAN_SPLIT/train
# VAL_DIR  : /content/dataset/HAM_CLEAN_SPLIT/val
# TEST_DIR : /content/dataset/HAM_CLEAN_SPLIT/test

# %%
classes = sorted([d for d in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, d))])
print("\nClasses:", classes)

print("\nCounts:")
for cls in classes:
    n_train = len(os.listdir(os.path.join(TRAIN_DIR, cls)))
    n_val   = len(os.listdir(os.path.join(VAL_DIR, cls)))
    n_test  = len(os.listdir(os.path.join(TEST_DIR, cls)))
    print(f"{cls:6s} | Train: {n_train:4d} | Val: {n_val:4d} | Test: {n_test:4d}")
# Out:
# Classes: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#
# Counts:
# akiec  | Train:  555 | Val:   49 | Test:   50
# bcc    | Train:  350 | Val:   75 | Test:   75
# bkl    | Train:  350 | Val:   75 | Test:   75
# df     | Train:  504 | Val:   17 | Test:   18
# mel    | Train:  350 | Val:   75 | Test:   75
# nv     | Train:  350 | Val:   75 | Test:   75
# vasc   | Train:  525 | Val:   21 | Test:   22

# %%
def count_aug(root):
    c = 0
    for cls in os.listdir(root):
        cls_dir = os.path.join(root, cls)
        if not os.path.isdir(cls_dir):
            continue
        for fn in os.listdir(cls_dir):
            if "_aug_" in fn:
                c += 1
    return c

print("\nAugmented in VAL :", count_aug(VAL_DIR))
print("Augmented in TEST:", count_aug(TEST_DIR))
# Out:
# Augmented in VAL : 0
# Augmented in TEST: 0

# %%
def show_random_images(root_dir, class_name, n=6):
    class_dir = os.path.join(root_dir, class_name)
    files_ = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
    if len(files_) == 0:
        print("No images found:", class_dir)
        return
    sample = random.sample(files_, min(n, len(files_)))

    cols = min(6, len(sample))
    rows = (len(sample) + cols - 1) // cols
    plt.figure(figsize=(cols*3, rows*3))
    for i, f in enumerate(sample):
        img = tf.keras.utils.load_img(os.path.join(class_dir, f), target_size=(224,224))
        plt.subplot(rows, cols, i+1)
        plt.imshow(img)
        plt.axis("off")
    plt.suptitle(f"{class_name} ({os.path.basename(root_dir)})", fontsize=14)
    plt.show()

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
SEED = 42

train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

class_names = train_ds.class_names
print("\nClass names:", class_names)
# Out:
# Found 2984 files belonging to 7 classes.
# Found 387 files belonging to 7 classes.
# Found 390 files belonging to 7 classes.
#
# Class names: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
mixed_precision.set_global_policy("mixed_float16")

AUTOTUNE = tf.data.AUTOTUNE
preprocess = tf.keras.applications.mobilenet_v2.preprocess_input

def preprocess_batch(x, y):
    x = tf.cast(x, tf.float32)
    x = preprocess(x)
    return x, y

train_ds = train_ds.map(preprocess_batch, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds   = val_ds.map(preprocess_batch,   num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
test_ds  = test_ds.map(preprocess_batch,  num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
def squeeze_excite_block(inputs, reduction=16):
    filters = inputs.shape[-1]  

    
    se = layers.GlobalAveragePooling2D()(inputs)
    se = layers.Reshape((1, 1, filters))(se)

 
    se = layers.Dense(filters // reduction,
                      activation="relu",
                      kernel_initializer="he_normal",
                      use_bias=False)(se)

    se = layers.Dense(filters,
                      activation="sigmoid",
                      kernel_initializer="he_normal",
                      use_bias=False)(se)

    
    x = layers.Multiply()([inputs, se])
    return x

# %%
NUM_CLASSES = len(class_names)

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)
base_model.trainable = False

inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = squeeze_excite_block(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32")(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_2… │ (None, 7, 7,      │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1,      │          0 │ global_average_p… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 80)  │    102,400 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1,      │    102,400 │ dense[0][0]       │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 7, 7,      │          0 │ mobilenetv2_1.00… │
# │                     │ 1280)             │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ multiply[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7)         │      8,967 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,471,751 (9.43 MB)
#  Trainable params: 213,767 (835.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks_1 = [
    keras.callbacks.ModelCheckpoint("mobilenetv2_se_best.keras", monitor="val_accuracy", save_best_only=True),
    keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=2),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=callbacks_1)
# Out:
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 103s 700ms/step - accuracy: 0.4413 - loss: 1.4826 - val_accuracy: 0.5659 - val_loss: 1.2253 - learning_rate: 0.0010
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6819 - loss: 0.8618 - val_accuracy: 0.5840 - val_loss: 1.1649 - learning_rate: 0.0010
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7436 - loss: 0.6906 - val_accuracy: 0.5969 - val_loss: 1.1398 - learning_rate: 0.0010
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7967 - loss: 0.5718 - val_accuracy: 0.6098 - val_loss: 1.1446 - learning_rate: 0.0010
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8262 - loss: 0.4945 - val_accuracy: 0.6176 - val_loss: 1.1608 - learning_rate: 0.0010
# Epoch 6/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8569 - loss: 0.4149 - val_accuracy: 0.6331 - val_loss: 1.1056 - learning_rate: 3.0000e-04
# Epoch 7/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8746 - loss: 0.3730 - val_accuracy: 0.6434 - val_loss: 1.1164 - learning_rate: 3.0000e-04
# Epoch 8/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8939 - loss: 0.3414 - val_accuracy: 0.6486 - val_loss: 1.1262 - learning_rate: 3.0000e-04
# Epoch 9/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9030 - loss: 0.3142 - val_accuracy: 0.6486 - val_loss: 1.1090 - learning_rate: 9.0000e-05
# Epoch 10/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9132 - loss: 0.2907 - val_accuracy: 0.6512 - val_loss: 1.1052 - learning_rate: 9.0000e-05

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("mobilenetv2_se_best.keras", monitor="val_accuracy", save_best_only=True),
    keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=2),
]

# %%
model = tf.keras.models.load_model("mobilenetv2_se_best.keras")

base_model = next(
    l for l in model.layers
    if isinstance(l, tf.keras.Model) and "mobilenetv2" in l.name.lower()
)

base_model.trainable = True
for layer in base_model.layers[:-54]:
    layer.trainable = False

for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 129s 777ms/step - accuracy: 0.5871 - loss: 1.3679 - val_accuracy: 0.5736 - val_loss: 1.2218 - learning_rate: 1.0000e-04
# Epoch 2/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7526 - loss: 0.6609 - val_accuracy: 0.5840 - val_loss: 1.2453 - learning_rate: 1.0000e-04
# Epoch 3/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8027 - loss: 0.5120 - val_accuracy: 0.6382 - val_loss: 1.0251 - learning_rate: 1.0000e-04
# Epoch 4/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8607 - loss: 0.3798 - val_accuracy: 0.6072 - val_loss: 1.1701 - learning_rate: 1.0000e-04
# Epoch 5/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8961 - loss: 0.2938 - val_accuracy: 0.6641 - val_loss: 1.1290 - learning_rate: 1.0000e-04
# Epoch 6/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9261 - loss: 0.1888 - val_accuracy: 0.6744 - val_loss: 1.1034 - learning_rate: 3.0000e-05
# Epoch 7/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9774 - loss: 0.0852 - val_accuracy: 0.6744 - val_loss: 1.1482 - learning_rate: 3.0000e-05
# Epoch 8/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9810 - loss: 0.0584 - val_accuracy: 0.6822 - val_loss: 1.1863 - learning_rate: 9.0000e-06
# Epoch 9/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9897 - loss: 0.0401 - val_accuracy: 0.6925 - val_loss: 1.2008 - learning_rate: 9.0000e-06
# Epoch 10/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9942 - loss: 0.0320 - val_accuracy: 0.6925 - val_loss: 1.1947 - learning_rate: 2.7000e-06
# Epoch 11/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9936 - loss: 0.0306 - val_accuracy: 0.6951 - val_loss: 1.2038 - learning_rate: 2.7000e-06
# Epoch 12/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9935 - loss: 0.0273 - val_accuracy: 0.6977 - val_loss: 1.2131 - learning_rate: 8.1000e-07
# Epoch 13/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9948 - loss: 0.0260 - val_accuracy: 0.7028 - val_loss: 1.2124 - learning_rate: 8.1000e-07
# Epoch 14/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9971 - loss: 0.0250 - val_accuracy: 0.7028 - val_loss: 1.2158 - learning_rate: 2.4300e-07
# Epoch 15/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9968 - loss: 0.0215 - val_accuracy: 0.7003 - val_loss: 1.2178 - learning_rate: 2.4300e-07
# Epoch 16/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9976 - loss: 0.0263 - val_accuracy: 0.7054 - val_loss: 1.2184 - learning_rate: 7.2900e-08
# Epoch 17/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9970 - loss: 0.0226 - val_accuracy: 0.7028 - val_loss: 1.2192 - learning_rate: 7.2900e-08
# Epoch 18/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9971 - loss: 0.0246 - val_accuracy: 0.7028 - val_loss: 1.2194 - learning_rate: 2.1870e-08
# Epoch 19/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9982 - loss: 0.0235 - val_accuracy: 0.7028 - val_loss: 1.2198 - learning_rate: 2.1870e-08
# Epoch 20/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9971 - loss: 0.0234 - val_accuracy: 0.7028 - val_loss: 1.2198 - learning_rate: 6.5610e-09
# Epoch 21/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9954 - loss: 0.0249 - val_accuracy: 0.7028 - val_loss: 1.2198 - learning_rate: 6.5610e-09

# %%
best_model = keras.models.load_model("mobilenetv2_se_best.keras")
test_loss, test_acc = best_model.evaluate(test_ds)
print(f"\nCLEAN Test accuracy: {test_acc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.6687 - loss: 1.2498
#
# CLEAN Test accuracy: 0.7051

# %%
y_true, y_pred = [], []

for images, labels in test_ds:
    probs = best_model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(probs, axis=1))

print("Macro F1:", f1_score(y_true, y_pred, average="macro"))
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(
    cm, annot=True, fmt="d",
    xticklabels=class_names, yticklabels=class_names,
    cmap="Blues"
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Macro F1: 0.7316004529609972
#               precision    recall  f1-score   support
#
#        akiec       0.65      0.52      0.58        50
#          bcc       0.74      0.85      0.79        75
#          bkl       0.67      0.64      0.65        75
#           df       0.76      0.89      0.82        18
#          mel       0.67      0.64      0.65        75
#           nv       0.69      0.69      0.69        75
#         vasc       0.91      0.95      0.93        22
#
#     accuracy                           0.71       390
#    macro avg       0.73      0.74      0.73       390
# weighted avg       0.70      0.71      0.70       390

# %%
import matplotlib.pyplot as plt

def plot_history(h, title_prefix=""):
    hist = h.history
    epochs = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(7,5))
    plt.plot(epochs, hist["accuracy"], label="train accuracy")
    plt.plot(epochs, hist["val_accuracy"], label="val accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"{title_prefix} Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

    
    plt.figure(figsize=(7,5))
    plt.plot(epochs, hist["loss"], label="train loss")
    plt.plot(epochs, hist["val_loss"], label="val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"{title_prefix} Loss")
    plt.legend()
    plt.grid(True)
    plt.show()


plot_history(history, "Feature Extraction (Frozen Backbone)")


plot_history(history_fine, "Fine Tuning (Unfrozen Backbone)")

# %%
import numpy as np

cm = confusion_matrix(y_true, y_pred)

specificity = []
for i in range(len(cm)):
    tn = np.sum(cm) - (np.sum(cm[i,:]) + np.sum(cm[:,i]) - cm[i,i])
    fp = np.sum(cm[:,i]) - cm[i,i]
    spec = tn / (tn + fp)
    specificity.append(spec)

for cls, spec in zip(class_names, specificity):
    print(f"{cls} Specificity: {spec:.4f}")
# Out:
# akiec Specificity: 0.9588
# bcc Specificity: 0.9270
# bkl Specificity: 0.9238
# df Specificity: 0.9866
# mel Specificity: 0.9238
# nv Specificity: 0.9270
# vasc Specificity: 0.9946

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true_bin = label_binarize(y_true, classes=range(NUM_CLASSES))
y_pred_prob = []

for images, _ in test_ds:
    y_pred_prob.extend(best_model.predict(images, verbose=0))

y_pred_prob = np.array(y_pred_prob)

for i in range(NUM_CLASSES):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={roc_auc:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.legend()
plt.title("ROC Curve (One-vs-Rest)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, f1_score


model = tf.keras.models.load_model("mobilenetv2_se_best.keras")


test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 678ms/step - accuracy: 0.6687 - loss: 1.2498
# Test Loss: 1.0942
# Test Accuracy: 0.7051

# %%
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

y_true = []
y_prob = []

for images, labels in test_ds:
    probs = best_model.predict(images, verbose=0)
    y_prob.extend(probs)
    y_true.extend(np.argmax(labels.numpy(), axis=1))

y_true = np.array(y_true)
y_prob = np.array(y_prob)

num_classes = y_prob.shape[1]


y_true_onehot = label_binarize(y_true, classes=range(num_classes))


macro_auc = roc_auc_score(
    y_true_onehot,
    y_prob,
    average="macro",
    multi_class="ovr"
)

print("Macro Average AUC:", macro_auc)
# Out:
# Macro Average AUC: 0.9437848097021403

# %%
model.save_weights("se.weights.h5")
